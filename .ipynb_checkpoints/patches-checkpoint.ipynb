# %%
from sklearn.feature_extraction import image
import cv2
import matplotlib.pyplot as plt
import numpy as np
import image_slicer
import os

# %%
img = cv2.imread(filelist[0])
img_plot = plt.imshow(img)

# %%
one_image = cv2.imread('normal.jpg')
print('Image shape: {}' . format(one_image.shape))

patches = aye
print('Patches shape: {}' .format(patches.shape))

fig=plt.figure(figsize=(20, 20))
columns = 4
rows = 4
for i in range(1, columns*rows+1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(patches)
plt.show()
# Out:
# Image shape: (1024, 1024, 3)
# Patches shape: (256, 256, 3)

# %%
i = image_slicer.slice('normal.jpg', 16)

# %%
filelist=os.listdir('/home/kazzastic/Documents/DataCleaning/Medical-Image-Cleaning/')
for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        filelist.remove(fichier)
# Out:
# ['normal_03_02.png', 'normal_01_03.png', 'normal_03_01.png', 'normal_03_03.png', 'normal_01_01.png', 'normal_03_04.png', 'normal_04_02.png', 'normal_02_04.png', 'normal_01_04.png', 'normal_01_02.png', 'normal_02_03.png', 'normal_04_03.png', 'normal_04_04.png', 'normal_02_02.png', 'normal_02_01.png', 'normal_04_01.png']

# %%
fig=plt.figure(figsize=(20, 20))
columns = 4
rows = 4
for i in range(len(filelist)):
    aye = cv2.imread(filelist[i])
    
for i in range(1, columns*rows+1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(aye[i-1])
plt.show()
